# %%
import pandas_datareader as pdr
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import numpy as np

# %%
#Start by importing stock data from Yahoo. We will be using the FAANG stock (Facebook, Amazon, Apple, Netflix, and Google)
#Our time period is January 1st, 2020 to May 11th, 2020 
fb = pdr.data.get_data_yahoo('FB', start = '2020-01-01', end = '2020-05-11')
fb
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2020-01-02  1898.010010  1864.150024  1875.000000  1898.010010  4029000
# 2020-01-03  1886.199951  1864.500000  1864.500000  1874.969971  3764400
# 2020-01-06  1903.689941  1860.000000  1860.000000  1902.880005  4061800
# 2020-01-07  1913.890015  1892.040039  1904.500000  1906.859985  4044900
# 2020-01-08  1911.000000  1886.439941  1898.040039  1891.969971  3508000
# ...                 ...          ...          ...          ...      ...
# 2020-05-05  2351.000000  2307.129883  2340.000000  2317.800049  3242500
# 2020-05-06  2357.449951  2320.000000  2329.439941  2351.260010  3117800
# 2020-05-07  2376.000000  2343.110107  2374.780029  2367.610107  3396400
# 2020-05-08  2387.239990  2357.000000  2372.139893  2379.610107  3206600
# 2020-05-11  2419.665039  2373.370117  2374.699951  2409.000000  3122791
#
#               Adj Close
# Date
# 2020-01-02  1898.010010
# 2020-01-03  1874.969971
# ...

# %%
amzn = pdr.data.get_data_yahoo('AMZN', start = '2020-01-01', end = '2020-05-11')
amzn
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2020-01-02  1898.010010  1864.150024  1875.000000  1898.010010  4029000
# 2020-01-03  1886.199951  1864.500000  1864.500000  1874.969971  3764400
# 2020-01-06  1903.689941  1860.000000  1860.000000  1902.880005  4061800
# 2020-01-07  1913.890015  1892.040039  1904.500000  1906.859985  4044900
# 2020-01-08  1911.000000  1886.439941  1898.040039  1891.969971  3508000
# ...                 ...          ...          ...          ...      ...
# 2020-05-05  2351.000000  2307.129883  2340.000000  2317.800049  3242500
# 2020-05-06  2357.449951  2320.000000  2329.439941  2351.260010  3117800
# 2020-05-07  2376.000000  2343.110107  2374.780029  2367.610107  3396400
# 2020-05-08  2387.239990  2357.000000  2372.139893  2379.610107  3206600
# 2020-05-11  2419.665039  2373.370117  2374.699951  2409.000000  3122791
#
#               Adj Close
# Date
# 2020-01-02  1898.010010
# 2020-01-03  1874.969971
# ...

# %%
aapl = pdr.data.get_data_yahoo('AAPL', start = '2020-01-01', end = '2020-05-11')
aapl
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2020-01-02  300.600006  295.190002  296.239990  300.350006  33870100.0
# 2020-01-03  300.579987  296.500000  297.149994  297.429993  36580700.0
# 2020-01-06  299.959991  292.750000  293.790009  299.799988  29596800.0
# 2020-01-07  300.899994  297.480011  299.839996  298.390015  27218000.0
# 2020-01-08  304.440002  297.160004  297.160004  303.190002  33019800.0
# ...                ...         ...         ...         ...         ...
# 2020-05-05  301.000000  294.459991  295.059998  297.559998  36937800.0
# 2020-05-06  303.239990  298.869995  300.459991  300.630005  35583400.0
# 2020-05-07  305.170013  301.970001  303.220001  303.739990  28803800.0
# 2020-05-08  310.350006  304.290009  305.640015  310.130005  33459600.0
# 2020-05-11  317.049988  307.239990  308.100006  315.010010  34806401.0
#
#              Adj Close
# Date
# 2020-01-02  298.829956
# 2020-01-03  295.924713
# 2020-01-06  298.282715
# ...

# %%
nflx = pdr.data.get_data_yahoo('NFLX', start = '2020-01-01', end = '2020-05-11')
nflx
# Out:
#                   High         Low        Open       Close   Volume  \
# Date
# 2020-01-02  329.980011  324.779999  326.100006  329.809998  4485800
# 2020-01-03  329.859985  325.529999  326.779999  325.899994  3806900
# 2020-01-06  336.359985  321.200012  323.119995  335.829987  5663100
# 2020-01-07  336.700012  330.299988  336.470001  330.750000  4703200
# 2020-01-08  342.700012  331.049988  331.489990  339.260010  7104500
# ...                ...         ...         ...         ...      ...
# 2020-05-05  431.000000  421.559998  427.559998  424.679993  6286300
# 2020-05-06  439.769989  426.390015  429.299988  434.260010  6660700
# 2020-05-07  438.880005  430.660004  436.890015  436.529999  5641900
# 2020-05-08  442.000000  433.640015  434.140015  435.549988  5049300
# 2020-05-11  444.889893  435.559998  436.329987  440.519989  5060796
#
#              Adj Close
# Date
# 2020-01-02  329.809998
# 2020-01-03  325.899994
# 2020-01-06  335.829987
# 2020-01-07  330.750000
# ...

# %%
goog = pdr.data.get_data_yahoo('GOOG', start = '2020-01-01', end = '2020-05-11')
goog
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2020-01-02  1368.140015  1341.550049  1341.550049  1367.369995  1406600
# 2020-01-03  1372.500000  1345.543945  1347.859985  1360.660034  1186400
# 2020-01-06  1396.500000  1350.000000  1350.000000  1394.209961  1732300
# 2020-01-07  1402.989990  1390.380005  1397.939941  1393.339966  1502700
# 2020-01-08  1411.579956  1390.839966  1392.079956  1404.319946  1528000
# ...                 ...          ...          ...          ...      ...
# 2020-05-05  1373.939941  1337.459961  1337.920044  1351.109985  1651500
# 2020-05-06  1371.119995  1347.290039  1361.689941  1347.300049  1215400
# 2020-05-07  1377.599976  1355.270020  1365.939941  1372.560059  1397600
# 2020-05-08  1398.760010  1375.479980  1383.130005  1388.369995  1386900
# 2020-05-11  1416.530029  1377.151978  1378.280029  1403.260010  1374025
#
#               Adj Close
# Date
# 2020-01-02  1367.369995
# 2020-01-03  1360.660034
# ...

# %%
#This line lets us plot the percentage change of the Adjusted closing price on a graph
fb['Adj Close'].pct_change().plot()

# %%
amzn['Adj Close'].pct_change().plot()

# %%
aapl['Adj Close'].pct_change().plot()

# %%
nflx['Adj Close'].pct_change().plot()

# %%
goog['Adj Close'].pct_change().plot()

# %%
#To convert our daily returns to montly returns, we use a resample function. ffill() is a forward fill that populates any missing value from the start date
#This allows us to produce the below graphs
fbmonthly = fb['Adj Close'].resample('M').ffill().pct_change()
fbmonthly.plot()

# %%
amznmonthly = amzn['Adj Close'].resample('M').ffill().pct_change()
amznmonthly.plot()

# %%
aaplmonthly = aapl['Adj Close'].resample('M').ffill().pct_change()
aaplmonthly.plot()

# %%
nflxmonthly = nflx['Adj Close'].resample('M').ffill().pct_change()
nflxmonthly.plot()

# %%
googmonthly = goog['Adj Close'].resample('M').ffill().pct_change()
googmonthly.plot()

# %%
#Price analysis - Looking at the plots, all of the FAANG shares have seen a dip in returns between February and March, likely due to the effects of COVID-19. 
#From the FAANG stocks, Apple has the highest monthly return in May at about 8%, followed by Facebook, Google, and Netflix at about 5% and Amazon having the lowest return at about -2%

# %%
#Here we are plotting cumulative returns. We first declare our variable and set this equal to the percentage change of the adjusted closing price + 1
#To explain why we add +1, if one day we make equal the benchmark, it represents a 100% cumulative return. This is also based off the cumulative return formula
#Finally, cumprod() is our cumulative product function
fb_cum_returns = (fb['Adj Close'].pct_change() + 1).cumprod()

# %%
#Here we are plotting the cumulative returns of our stocks, 0.1,0.1,0.8,0.8 represents the position of the axis. 
fig = plt.figure()
ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
fb_cum_returns.plot()
ax1.set_xlabel("Date")
ax1.set_ylabel("Return")
ax1.set_title("Facebook Cumulative Returns")
plt.show()

# %%
amzn_cum_returns = (amzn['Adj Close'].pct_change() + 1).cumprod()

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
amzn_cum_returns.plot()
ax1.set_xlabel("Date")
ax1.set_ylabel("Return")
ax1.set_title("Amazon Cumulative Returns")
plt.show()

# %%
aapl_cum_returns = (aapl['Adj Close'].pct_change() + 1).cumprod()

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
aapl_cum_returns.plot()
ax1.set_xlabel("Date")
ax1.set_ylabel("Return")
ax1.set_title("Apple Cumulative Returns")
plt.show()

# %%
nflx_cum_returns = (nflx['Adj Close'].pct_change() + 1).cumprod()

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
nflx_cum_returns.plot()
ax1.set_xlabel("Date")
ax1.set_ylabel("Return")
ax1.set_title("Netflix Cumulative Returns")
plt.show()

# %%
goog_cum_returns = (goog['Adj Close'].pct_change() + 1).cumprod()

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
goog_cum_returns.plot()
ax1.set_xlabel("Date")
ax1.set_ylabel("Return")
ax1.set_title("Google Cumulative Returns")
plt.show()

# %%
#Analysis - We can see that the cumulative returns of Facebook, Google and Apple follow a similar pattern. Netflix and Amazon also share a similar trend
#As previously mentioned all shares suffered due to the COVID-19 shock however they appear to be rebounding

# %%
tickers = ["FB", "AMZN", "AAPL", "NFLX", "GOOG"]
FAANG = pdr.get_data_yahoo(tickers, start = "2020-01-01", end = "2020-05-11")

# %%
FAANG_daily_returns = FAANG['Adj Close'].pct_change()
FAANG_monthly_returns = FAANG['Adj Close'].resample('M').ffill().pct_change()

# %%
#Plotting and comparing the monthly returns of the FAANG stocks
fig = plt.figure()
(FAANG_monthly_returns + 1).cumprod().plot()
plt.show()

# %%
#Note that the first month is NaN (Not a number) as cumulative returns requires the previous month's data to compute (December 2019) which we do not use
(FAANG_monthly_returns + 1).cumprod()
# Out:
# Symbols           FB      AMZN      AAPL      NFLX      GOOG
# Date
# 2020-01-31       NaN       NaN       NaN       NaN       NaN
# 2020-02-29  0.953246  0.937786  0.885298  1.069373  0.933832
# 2020-03-31  0.826111  0.970628  0.823539  1.088122  0.810756
# 2020-04-30  1.013868  1.231630  0.951495  1.216639  0.940337
# 2020-05-31  1.055817  1.199271  1.022947  1.276537  0.978407

# %%
#Calculating the Covariance of each of our stock
print(FAANG_monthly_returns.cov())
# Out:
# Symbols        FB      AMZN      AAPL      NFLX      GOOG
# Symbols
# FB       0.023794  0.017833  0.017356  0.005891  0.019540
# AMZN     0.017833  0.022164  0.014007  0.004357  0.013763
# AAPL     0.017356  0.014007  0.015758  0.003315  0.014877
# NFLX     0.005891  0.004357  0.003315  0.001778  0.004607
# GOOG     0.019540  0.013763  0.014877  0.004607  0.016310

# %%
print(FAANG_monthly_returns.corr())
# Out:
# Symbols        FB      AMZN      AAPL      NFLX      GOOG
# Symbols
# FB       1.000000  0.776534  0.896339  0.905716  0.991881
# AMZN     0.776534  1.000000  0.749521  0.694102  0.723859
# AAPL     0.896339  0.749521  1.000000  0.626236  0.927947
# NFLX     0.905716  0.694102  0.626236  1.000000  0.855502
# GOOG     0.991881  0.723859  0.927947  0.855502  1.000000

# %%
print(FAANG_monthly_returns.std())
# Out:
# Symbols
# FB      0.154253
# AMZN    0.148875
# AAPL    0.125531
# NFLX    0.042163
# GOOG    0.127712
# dtype: float64

# %%
#Fetching our price data for the FAANG stocks 
tickers = ['FB', 'AMZN', 'AAPL', 'NFLX', 'GOOG']
price_data = pdr.data.get_data_yahoo(tickers,
                           start = '2020-01-01',
                           end = '2020-05-11')['Adj Close']

# %%
#Here we are calculating the logarithmic return of the price data of FAANG - the Shift method shifts the values by 1 column
log_ret = np.log(price_data/price_data.shift(1))

# %%
#Creating the covariance matrix, we multiply by 252 to represent the number of trading days in a year
cov_mat = log_ret.cov() * 252
print(cov_mat)
# Out:
# Symbols        FB      AMZN      AAPL      NFLX      GOOG
# Symbols
# FB       0.330438  0.177009  0.302142  0.197775  0.272207
# AMZN     0.177009  0.205774  0.196498  0.182907  0.175606
# AAPL     0.302142  0.196498  0.366451  0.218175  0.287578
# NFLX     0.197775  0.182907  0.218175  0.291019  0.189494
# GOOG     0.272207  0.175606  0.287578  0.189494  0.278056

# %%
# Simulating 10000 portfolios
num_port = 10000
# Creating an empty array to store portfolio weights
all_wts = np.zeros((num_port, len(price_data.columns)))
# Creating an empty array to store portfolio returns
port_returns = np.zeros((num_port))
# Creating an empty array to store portfolio risks
port_risk = np.zeros((num_port))
# Creating an empty array to store portfolio sharpe ratio
sharpe_ratio = np.zeros((num_port))

# %%
#Setting up the for loop to simulate the returns and risks of 10,000.
for i in range(num_port):
  wts = np.random.uniform(size = len(price_data.columns))
  wts = wts/np.sum(wts)

 #The colon in this array simply means that the array goes front i to the end of the array
  all_wts[i,:] = wts
  
  #We then bring together the returns of our portfolio and save this in our array 
  port_ret = np.sum(log_ret.mean() * wts)
  port_ret = (port_ret + 1) ** 252 - 1
  
  
  port_returns[i] = port_ret
  
  
  #Saving the standard deviation of the FAANG stock in yet another array
  port_sd = np.sqrt(np.dot(wts.T, np.dot(cov_mat, wts)))
  
  port_risk[i] = port_sd
  
  #Saving out Sharpe ratio in its own array, we also assume a risk free rate of 0%
  sr = port_ret / port_sd
  sharpe_ratio[i] = sr

# %%
#Finding the minimum variance weights of each of our FAANG stocks
names = price_data.columns
min_var = all_wts[port_risk.argmin()]
print(min_var)
# Out:
# [0.06002818 0.7167522  0.00833547 0.06456963 0.15031452]

# %%
#Finding the maximum Sharpe Ratio weights of each of our FAANG stocks
max_sr = all_wts[sharpe_ratio.argmax()]
print(max_sr)
# Out:
# [0.00634579 0.47367963 0.02156821 0.49543572 0.00297065]

# %%
#This is our maximum Sharpe Ratio, a Sharpe ratio of 2.3 is considered good
print(sharpe_ratio.max())
# Out:
# 2.3073402051834506

# %%
#This is our minimum possible risk portfolio. 0.44 is the Beta of the minimum risk portfolio which means that the stock moves by about 44% of the index i.e. it is relatively safe 
print(port_risk.min())
# Out:
# 0.44514626174170524

# %%
#Plotting our minimum variance portfolio weights for visualization
min_var = pd.Series(min_var, index=names)
min_var = min_var.sort_values()
fig = plt.figure()
ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
ax1.set_xlabel('Asset')
ax1.set_ylabel("Weights")
ax1.set_title("Minimum Variance Portfolio weights")
min_var.plot(kind = 'bar')
plt.show();

# %%
#The Tangency portfolio weights is another way to say that we are looking for the weights that would maximize our Sharpe Ratio
max_sr = pd.Series(max_sr, index=names)
max_sr = max_sr.sort_values()
fig = plt.figure()
ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
ax1.set_xlabel('Asset')
ax1.set_ylabel("Weights")
ax1.set_title("Tangency Portfolio weights")
max_sr.plot(kind = 'bar')
plt.show();

# %%
#Putting this all together, we put together the Efficient Frontier, with the y axis representing our returns, and the x axis representing risk
#The most optimal portfolio is on the upper left, which represent the portfolio with the lowest risk and the highest return
#The least optimal portfolio is on the bottom right, with a beta of 0.58 and a return of only 20%
#Most portfolios typically lie in the middle of the efficient frontier
fig = plt.figure()
ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
ax1.set_xlabel('Risk')
ax1.set_ylabel("Returns")
ax1.set_title("Portfolio optimization and Efficient Frontier")
plt.scatter(port_risk, port_returns)
plt.show();
